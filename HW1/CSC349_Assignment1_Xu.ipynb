# %% [markdown]
# <a href="https://colab.research.google.com/github/computerpanda876/CSC349/blob/main/HW1/CSC349_Assignment1_Xu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis
# ## Question 1.
# Running python code from Colab, saving to both gdrive and Github (for better sharing and version control).
# ## Question 2.
# All **Module 0** notebooks executed successfully in Colab on the first try for me.
# ## Question 3.
# I created my repository through Github's web interface, created a HW1 folder, and saved my Jupyter Notebook files both to gdrive and Github, as well as a directory on my machine.
# ## Question 4.
# Establishing a strong command of basic Python data structure and syntax is critical before moving onto core machine learning algorithms because without it, it would be impossible to actually write code.
